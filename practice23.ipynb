# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/training-ml/Files/main/raw_data.csv")
df.head(10)
# Out:
#       id Employee Full Name         DOB                         email  gender  \
# 0  201.0        Salim Pound  02-12-2018           spound0@spotify.com    Male
# 1  202.0     Madelene Lutas   9/20/2018                mlutas1@si.edu  Female
# 2  203.0   Dolli Swanbourne  11/18/2018  dswanbourne2@istockphoto.com  Female
# 3  204.0    Graeme Croisier   9/29/2018                           NaN    Male
# 4  205.0     Jillana Physic   4/19/2018       jphysic4@yellowbook.com  Female
# 5  206.0    Anetta Yokelman   4/26/2018       ayokelman5@berkeley.edu  Female
# 6  207.0  Modesta Batterson   3/28/2018                           NaN  Female
# 7  208.0        Melina Boon  12/18/2017              mboon7@weibo.com    Male
# 8  209.0          Nomi Warn   1/16/2018              nwarn8@sogou.com  Female
# 9    NaN                NaN         NaN                           NaN     NaN
#
#      Company Country           Income.1  Income.2
# 0     Google   India  $46476.6380809961     529.0
# ...

# %%
df.loc[9]=[210,'jim carry','1/1/1970','jimcarry@gmail.com','male','amazon','usa',12349.556,2365]
df.head()
# Out:
#       id Employee Full Name         DOB                         email  gender  \
# 0  201.0        Salim Pound  02-12-2018           spound0@spotify.com    Male
# 1  202.0     Madelene Lutas   9/20/2018                mlutas1@si.edu  Female
# 2  203.0   Dolli Swanbourne  11/18/2018  dswanbourne2@istockphoto.com  Female
# 3  204.0    Graeme Croisier   9/29/2018                           NaN    Male
# 4  205.0     Jillana Physic   4/19/2018       jphysic4@yellowbook.com  Female
#
#      Company Country           Income.1  Income.2
# 0     Google   India  $46476.6380809961     529.0
# 1     Amazon     USA  $54174.6879482406     720.0
# 2      Intel     UAS                NaN     234.0
# 3  Accenture  Canada  $46784.6308786279     657.0
# 4  Accenture     NaN  $57486.4955595568    1947.0

# %%
df.head(10)
# Out:
#       id Employee Full Name         DOB                         email  gender  \
# 0  201.0        Salim Pound  02-12-2018           spound0@spotify.com    Male
# 1  202.0     Madelene Lutas   9/20/2018                mlutas1@si.edu  Female
# 2  203.0   Dolli Swanbourne  11/18/2018  dswanbourne2@istockphoto.com  Female
# 3  204.0    Graeme Croisier   9/29/2018                           NaN    Male
# 4  205.0     Jillana Physic   4/19/2018       jphysic4@yellowbook.com  Female
# 5  206.0    Anetta Yokelman   4/26/2018       ayokelman5@berkeley.edu  Female
# 6  207.0  Modesta Batterson   3/28/2018                           NaN  Female
# 7  208.0        Melina Boon  12/18/2017              mboon7@weibo.com    Male
# 8  209.0          Nomi Warn   1/16/2018              nwarn8@sogou.com  Female
# 9  210.0          jim carry    1/1/1970            jimcarry@gmail.com    male
#
#      Company Country           Income.1  Income.2
# 0     Google   India  $46476.6380809961     529.0
# ...

# %%
df.at[3,'email']='glareme.crossier @ gmail.com'
df.at[6,'email']='modesta.batterson @ gmail.com'

# %%
df.head(10)
# Out:
#       id Employee Full Name         DOB                          email  \
# 0  201.0        Salim Pound  02-12-2018            spound0@spotify.com
# 1  202.0     Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2  203.0   Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3  204.0    Graeme Croisier   9/29/2018   glareme.crossier @ gmail.com
# 4  205.0     Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5  206.0    Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6  207.0  Modesta Batterson   3/28/2018  modesta.batterson @ gmail.com
# 7  208.0        Melina Boon  12/18/2017               mboon7@weibo.com
# 8  209.0          Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9  210.0          jim carry    1/1/1970             jimcarry@gmail.com
#
#    gender    Company Country           Income.1  Income.2
# 0    Male     Google   India  $46476.6380809961     529.0
# 1  Female     Amazon     USA  $54174.6879482406     720.0
# ...

# %%
df['Country'].replace({'UAS':'USA'},inplace=True)

# %%
df['Country'].fillna(value=df['Country'].mode()[0],inplace=True)

# %%
df.head(10)
# Out:
#       id Employee Full Name         DOB                          email  \
# 0  201.0        Salim Pound  02-12-2018            spound0@spotify.com
# 1  202.0     Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2  203.0   Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3  204.0    Graeme Croisier   9/29/2018   glareme.crossier @ gmail.com
# 4  205.0     Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5  206.0    Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6  207.0  Modesta Batterson   3/28/2018  modesta.batterson @ gmail.com
# 7  208.0        Melina Boon  12/18/2017               mboon7@weibo.com
# 8  209.0          Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9  210.0          jim carry    1/1/1970             jimcarry@gmail.com
#
#    gender    Company Country           Income.1  Income.2
# 0    Male     Google   India  $46476.6380809961     529.0
# 1  Female     Amazon     USA  $54174.6879482406     720.0
# ...

# %%
df.shape
# Out:
# (20, 9)

# %%
df['Income.1']=df['Income.1'].str.replace("$"," ")
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11192\3049049714.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Income.1']=df['Income.1'].str.replace("$"," ")
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018   glareme.crossier @ gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018  modesta.batterson @ gmail.com
# ...

# %%
df["Income.1"]=df["Income.1"].replace(" ",np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20 non-null     float64
#  1   Employee Full Name  20 non-null     object
#  2   DOB                 20 non-null     object
#  3   email               20 non-null     object
#  4   gender              20 non-null     object
#  5   Company             20 non-null     object
#  6   Country             20 non-null     object
#  7   Income.1            13 non-null     object
#  8   Income.2            18 non-null     float64
# dtypes: float64(2), object(7)
# memory usage: 1.5+ KB

# %%
df["Income.1"]=df["Income.1"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20 non-null     float64
#  1   Employee Full Name  20 non-null     object
#  2   DOB                 20 non-null     object
#  3   email               20 non-null     object
#  4   gender              20 non-null     object
#  5   Company             20 non-null     object
#  6   Country             20 non-null     object
#  7   Income.1            13 non-null     float64
#  8   Income.2            18 non-null     float64
# dtypes: float64(3), object(6)
# memory usage: 1.5+ KB

# %%
df["Income.1"].fillna(df["Income.1"].mean(),inplace=True)

# %%
df['Income.2'].fillna(df['Income.2'].mean(),inplace=True)

# %%
df['Total income']=np.ceil(df['Income.1']+df['Income.2'])

# %%
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018   glareme.crossier @ gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018  modesta.batterson @ gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            jim carry    1/1/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df['DOB']=pd.to_datetime(df["DOB"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20 non-null     float64
#  1   Employee Full Name  20 non-null     object
#  2   DOB                 20 non-null     datetime64[ns]
#  3   email               20 non-null     object
#  4   gender              20 non-null     object
#  5   Company             20 non-null     object
#  6   Country             20 non-null     object
#  7   Income.1            20 non-null     float64
#  8   Income.2            20 non-null     float64
#  9   Total income        20 non-null     float64
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 1.7+ KB

# %%
df['DOB'].dt.strftime('%d-%m-%y')
# Out:
# 0     12-02-18
# 1     20-09-18
# 2     18-11-18
# 3     29-09-18
# 4     19-04-18
# 5     26-04-18
# 6     28-03-18
# 7     18-12-17
# 8     16-01-18
# 9     01-01-70
# 10    15-04-18
# 11    26-06-18
# 12    16-04-18
# 13    21-08-18
# 14    08-04-18
# 15    14-02-18
# 16    27-09-18
# 17    07-01-18
# 18    21-05-18
# 19    30-10-18
# Name: DOB, dtype: object

# %%
df
# Out:
#        id   Employee Full Name        DOB                          email  \
# 0   201.0          Salim Pound 2018-02-12            spound0@spotify.com
# 1   202.0       Madelene Lutas 2018-09-20                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne 2018-11-18   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier 2018-09-29   glareme.crossier @ gmail.com
# 4   205.0       Jillana Physic 2018-04-19        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman 2018-04-26        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson 2018-03-28  modesta.batterson @ gmail.com
# 7   208.0          Melina Boon 2017-12-18               mboon7@weibo.com
# 8   209.0            Nomi Warn 2018-01-16               nwarn8@sogou.com
# 9   210.0            jim carry 1970-01-01             jimcarry@gmail.com
# 10  211.0       Charleen Auden 2018-04-15                caudena@nba.com
# 11  212.0          Dame Povele 2018-06-26         dpoveleb@bloglovin.com
# ...

# %%
df[['First_name','Last_name']]=df['Employee Full Name'].str.split(' ',expand=True)

# %%
df
# Out:
#        id   Employee Full Name        DOB                          email  \
# 0   201.0          Salim Pound 2018-02-12            spound0@spotify.com
# 1   202.0       Madelene Lutas 2018-09-20                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne 2018-11-18   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier 2018-09-29   glareme.crossier @ gmail.com
# 4   205.0       Jillana Physic 2018-04-19        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman 2018-04-26        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson 2018-03-28  modesta.batterson @ gmail.com
# 7   208.0          Melina Boon 2017-12-18               mboon7@weibo.com
# 8   209.0            Nomi Warn 2018-01-16               nwarn8@sogou.com
# 9   210.0            jim carry 1970-01-01             jimcarry@gmail.com
# 10  211.0       Charleen Auden 2018-04-15                caudena@nba.com
# 11  212.0          Dame Povele 2018-06-26         dpoveleb@bloglovin.com
# ...

# %%
frst_col=df.pop('First_name')
df.insert(0,'First_name','frst_col')
df
# Out:
#    First_name     id   Employee Full Name        DOB  \
# 0    frst_col  201.0          Salim Pound 2018-02-12
# 1    frst_col  202.0       Madelene Lutas 2018-09-20
# 2    frst_col  203.0     Dolli Swanbourne 2018-11-18
# 3    frst_col  204.0      Graeme Croisier 2018-09-29
# 4    frst_col  205.0       Jillana Physic 2018-04-19
# 5    frst_col  206.0      Anetta Yokelman 2018-04-26
# 6    frst_col  207.0    Modesta Batterson 2018-03-28
# 7    frst_col  208.0          Melina Boon 2017-12-18
# 8    frst_col  209.0            Nomi Warn 2018-01-16
# 9    frst_col  210.0            jim carry 1970-01-01
# 10   frst_col  211.0       Charleen Auden 2018-04-15
# 11   frst_col  212.0          Dame Povele 2018-06-26
# 12   frst_col  213.0    Jesse Engelbrecht 2018-04-16
# 13   frst_col  214.0       Camey Barensen 2018-08-21
# 14   frst_col  215.0     Alexandro Sember 2018-04-08
# 15   frst_col  216.0         Myrtia Towne 2018-02-14
# 16   frst_col  217.0       Shay Cakebread 2018-09-27
# ...

# %%
sec_col=df.pop('Last_name')
df.insert(1,'Last_name',sec_col)
df
# Out:
#    First_name    Last_name     id   Employee Full Name        DOB  \
# 0    frst_col        Pound  201.0          Salim Pound 2018-02-12
# 1    frst_col        Lutas  202.0       Madelene Lutas 2018-09-20
# 2    frst_col   Swanbourne  203.0     Dolli Swanbourne 2018-11-18
# 3    frst_col     Croisier  204.0      Graeme Croisier 2018-09-29
# 4    frst_col       Physic  205.0       Jillana Physic 2018-04-19
# 5    frst_col     Yokelman  206.0      Anetta Yokelman 2018-04-26
# 6    frst_col    Batterson  207.0    Modesta Batterson 2018-03-28
# 7    frst_col         Boon  208.0          Melina Boon 2017-12-18
# 8    frst_col         Warn  209.0            Nomi Warn 2018-01-16
# 9    frst_col        carry  210.0            jim carry 1970-01-01
# 10   frst_col        Auden  211.0       Charleen Auden 2018-04-15
# 11   frst_col       Povele  212.0          Dame Povele 2018-06-26
# 12   frst_col  Engelbrecht  213.0    Jesse Engelbrecht 2018-04-16
# ...
